# %%
import pandas as pd
df_pfcap = pd.read_excel(r"F:\Downloads\RepNew_1712_agg.xlsx")
df_latest = pd.read_csv(r"F:\Downloads\director-firm-year-event_happened_19122021.csv", sep=";", decimal=',')

# %%
#show first dataframe
df_pfcap[:5]

# %%
#show second dataframe
df_latest[:5]

# %%
#merge both dataframes based on IDS and do a left merge
df_director_firm_year_merge_pfcap = df_latest.merge(df_pfcap, how="left", on=["DirectorID", "Year"])
df_director_firm_year_merge_pfcap

# %%
#export to csv
df_director_firm_year_merge_pfcap.to_csv(r"C:\Users\hannes\Desktop\director-firm-years-with-glassdoor_1217.csv", sep=";", decimal=',', index=False)
